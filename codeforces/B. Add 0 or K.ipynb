# %%
import sys
input = sys.stdin.readline

# ---- Core logic for a single test case ----
def solve_case(n, k, arr):
    mx = max(arr)
    res = []
    for ai in arr:
        diff = (mx - ai) % k
        res.append(ai + diff)
    return res

# ---- Handles multiple test cases with standard input ----
def solve():
    t = int(input())
    for _ in range(t):
        n, k = map(int, input().split())
        arr = list(map(int, input().split()))
        result = solve_case(n, k, arr)
        print(*result)

# ---- Local testing (no need for stdin) ----
def run_local_tests():
    test_cases = [
        # (n, k, arr)
        (3, 3, [2, 7, 1]),
        (4, 5, [2, 9, 16, 14]),
        (4, 1, [1, 2, 3, 4]),
        (5, 2, [5, 6, 7, 8, 9]),
        (2, 10, [7, 9]),
        (1, 1000000000, [1]),
        (1, 371, [1000000000]),
        (3, 6, [1, 3, 5]),
    ]

    for i, (n, k, arr) in enumerate(test_cases, 1):
        result = solve_case(n, k, arr)
        print(f"Test {i}: input=({n}, {k}, {arr}) -> output={result}")

# ---- Main entry ----
if __name__ == "__main__":
    # Uncomment this to run with actual stdin input (Codeforces mode)
    # solve()

    # Run local tests instead
    run_local_tests()
# Out:
# Test 1: input=(3, 3, [2, 7, 1]) -> output=[4, 7, 1]
# Test 2: input=(4, 5, [2, 9, 16, 14]) -> output=[6, 11, 16, 16]
# Test 3: input=(4, 1, [1, 2, 3, 4]) -> output=[1, 2, 3, 4]
# Test 4: input=(5, 2, [5, 6, 7, 8, 9]) -> output=[5, 7, 7, 9, 9]
# Test 5: input=(2, 10, [7, 9]) -> output=[9, 9]
# Test 6: input=(1, 1000000000, [1]) -> output=[1]
# Test 7: input=(1, 371, [1000000000]) -> output=[1000000000]
# Test 8: input=(3, 6, [1, 3, 5]) -> output=[5, 5, 5]

# %%
import sys
input = sys.stdin.readline

# ---- Core logic for a single test case ----
def solve_case(n, k, arr):
    mx = max(arr)
    res = []
    for ai in arr:
        diff = (mx - ai) % k
        res.append(ai + diff)
    return res

# ---- Handles multiple test cases with standard input (for Codeforces) ----
def solve():
    t = int(input())
    for _ in range(t):
        n, k = map(int, input().split())
        arr = list(map(int, input().split()))
        result = solve_case(n, k, arr)
        print(*result)

# ---- Local test using provided sample ----
def run_local_sample():
    input_data = """8
3 3
2 7 1
4 5
2 9 16 14
4 1
1 2 3 4
5 2
5 6 7 8 9
2 10
7 9
1 1000000000
1
1 371
1000000000
3 6
1 3 5
"""
    expected_output = """8 10 10
7 14 21 14
2 2 4 4
9 6 9 12 9
77 99
1000000000000000001
1000000000
25 15 5
"""
    from io import StringIO
    sys.stdin = StringIO(input_data.strip())
    solve()
    print("\nExpected output:")
    print(expected_output.strip())

# ---- Main entry ----
if __name__ == "__main__":
    # For Codeforces submission, uncomment this:
    # solve()

    # For local testing, keep this:
    run_local_sample()
